# %%
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread("people2.jpg")    #IMPORTANDO IMAGEM
b, g, r = cv2.split(img)
img = cv2.merge((r, g, b))
img_cinza = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
img_cinza.shape
# Out:
# (537, 1023)

# %%
plt.imshow(img)

# %%
plt.imshow(img_cinza, cmap ='gray')
